# %%
import pandas as pd
import numpy as np

file = pd.read_csv('provincess (3).csv')
#file=file.dropna(axis=0)
#file=file.drop(file.index[4],inplace=True)
#file=file.reset_index()
file = file.drop(file.columns[[10,3,8,9,11,12]],axis=1)
file.corr(method='pearson')

#r.to_csv('data.csv')
#Very Strong correlations;
#1) Rates of children in lone-parent families and Rates of Households with Police-Reported Violence against Children 
    #; 93.8% (2011) and 94.2% (2016).
#2) Youth Crime Severity Index and Rates of Households with Police-Reported Violence against Children are 
    #; 87.8% (2011) and 91.6% (2016).
#3) Rate of Population with no Degree and Rates of Lone parent families; 
    #; 85.7% (2011) and 92% (2016).
#4) Rate of Households with Police-Reported Violence against Children and Rate of Population with no Degree
    #; 87.8% (2011) and 88.5% (2016).
#5) Rate of Youth in Correctional Services and Rate of Children in Foster Care.
    #; 75.7% (2011) and 70.9% (2016).
#6) Daily Smokers per Region & Lone-parent families; 92.4 (2011).
#7) Daily Smokers & No Degree;94% 
#8) Daily Smokers & Household Violence; 90.9%.

#Moderately strong correlations; 

#1) Vegetable Consumption and Household violence; -61.5% (2011; negatively correlated).
#2) Rate of population with no degree and Youth crime rate
    #; 68.8 (2011) and 72.9%
#3) Daily Smokers and Youth Crime Severity Index; 68.6%.
#4) Alcohol Overdose Rate and Rates of Households with Violence; 66.8% (2016)

#KEY TAKEAWAYS
#___________________________________________________________________________________________________________
#A) Violence in the household is more likely to occur in lone-parent families, and plays a big role in
    # increasing the likelihood that a child will commit a more serious crime (we can tell that its not inasmuch volume because 
    # there is not a strong correlation between rate of lone-parent and rate of youth charged per 100,000 youth).
#B) 2) suggests that violence in the household perpetuates children in such homes to become violent.
#C) 4) suggests that there is a high likelihood that the less educated a given population is, 
    #the more prone parents are to abuse their children.
#D) Regions with a higher rate of daily smokers are prone to have higher levels of people with no degree, have lone parents,
    #,and have parents that abuse their children.
#E) Places with higher Children in Care have more kids committing crime.
# Out:
#                                                     Rate of Youth Charged per 100,000 population 2011  \
# Rate of Youth Charged per 100,000 population 2011                                            1.000000
# Rate of CYIC 2011                                                                            0.635588
# Rate of Youth Charged per 100,000 population 2016                                            0.983519
# Rate of Children Living Low-Income Households 2016                                           0.043529
# Rate of Population with No Degree 2016                                                       0.338506
# Youth Crime Severity Index 2011                                                              0.846743
# Rate of Children in lone-parent families 2016                                                0.432810
# Rate of Children in lone-parent families 2011                                                0.428049
# Rates of households with violence 2011                                                       0.538931
# Rates of households with violence 2016                                                       0.568104
# Rate of Population with No Degree 2011                                                       0.382183
# Average Household Size                                                                       0.173212
# Vegetable Consumption per Region 2011                                                       -0.461343
# Rate of Youth in Correctional Services 2011                                                  0.781349
# Rate of Youth in Correctional Services 2016                                                  0.641159
# Alcohol Overdose Rate                                                                        0.581050
# Suicide Rate 2011                                                                            0.249146
# Suicide Rate 2016                                                                            0.419294
# Homicide Rate 2011                                                                           0.300095
# Homicide Rate 2016                                                                           0.396558
# Daily Smokers per Region 2016                                                                0.381827
# Daily Smokers per Region 2011                                                                0.412415
#
#                                                     Rate of CYIC 2011  \
# Rate of Youth Charged per 100,000 population 2011            0.635588
# Rate of CYIC 2011                                            1.000000
# Rate of Youth Charged per 100,000 population 2016            0.705091
# Rate of Children Living Low-Income Households 2016           0.147679
# Rate of Population with No Degree 2016                       0.388663
# Youth Crime Severity Index 2011                              0.739079
# Rate of Children in lone-parent families 2016                0.484712
# Rate of Children in lone-parent families 2011                0.508538
# Rates of households with violence 2011                       0.564025
# Rates of households with violence 2016                       0.601320
# Rate of Population with No Degree 2011                       0.392333
# Average Household Size                                       0.286621
# Vegetable Consumption per Region 2011                       -0.363625
# Rate of Youth in Correctional Services 2011                  0.757253
# Rate of Youth in Correctional Services 2016                  0.667074
# Alcohol Overdose Rate                                        0.609035
# Suicide Rate 2011                                            0.262836
# Suicide Rate 2016                                            0.434925
# Homicide Rate 2011                                           0.312855
# Homicide Rate 2016                                           0.521534
# Daily Smokers per Region 2016                                0.402430
# Daily Smokers per Region 2011                                0.461702
#
#                                                     Rate of Youth Charged per 100,000 population 2016  \
# Rate of Youth Charged per 100,000 population 2011                                            0.983519
# Rate of CYIC 2011                                                                            0.705091
# Rate of Youth Charged per 100,000 population 2016                                            1.000000
# Rate of Children Living Low-Income Households 2016                                           0.025266
# Rate of Population with No Degree 2016                                                       0.297200
# Youth Crime Severity Index 2011                                                              0.832524
# Rate of Children in lone-parent families 2016                                                0.403650
# Rate of Children in lone-parent families 2011                                                0.412541
# Rates of households with violence 2011                                                       0.519076
# Rates of households with violence 2016                                                       0.553051
# Rate of Population with No Degree 2011                                                       0.346539
# Average Household Size                                                                       0.276108
# Vegetable Consumption per Region 2011                                                       -0.450445
# Rate of Youth in Correctional Services 2011                                                  0.793926
# Rate of Youth in Correctional Services 2016                                                  0.701129
# Alcohol Overdose Rate                                                                        0.615727
# Suicide Rate 2011                                                                            0.192710
# Suicide Rate 2016                                                                            0.374009
# Homicide Rate 2011                                                                           0.229549
# Homicide Rate 2016                                                                           0.484720
# Daily Smokers per Region 2016                                                                0.351810
# Daily Smokers per Region 2011                                                                0.393463
#
#                                                     Rate of Children Living Low-Income Households 2016  \
# Rate of Youth Charged per 100,000 population 2011                                            0.043529
# Rate of CYIC 2011                                                                            0.147679
# Rate of Youth Charged per 100,000 population 2016                                            0.025266
# Rate of Children Living Low-Income Households 2016                                           1.000000
# Rate of Population with No Degree 2016                                                       0.335655
# Youth Crime Severity Index 2011                                                              0.135691
# Rate of Children in lone-parent families 2016                                                0.340260
# Rate of Children in lone-parent families 2011                                                0.473659
# Rates of households with violence 2011                                                      -0.185717
# Rates of households with violence 2016                                                      -0.210902
# Rate of Population with No Degree 2011                                                       0.267113
# Average Household Size                                                                       0.095491
# Vegetable Consumption per Region 2011                                                       -0.599164
# Rate of Youth in Correctional Services 2011                                                  0.425904
# Rate of Youth in Correctional Services 2016                                                  0.349254
# Alcohol Overdose Rate                                                                       -0.217784
# Suicide Rate 2011                                                                           -0.371731
# Suicide Rate 2016                                                                            0.116131
# Homicide Rate 2011                                                                           0.198797
# Homicide Rate 2016                                                                           0.117713
# Daily Smokers per Region 2016                                                                0.329166
# Daily Smokers per Region 2011                                                                0.042891
#
#                                                     Rate of Population with No Degree 2016  \
# Rate of Youth Charged per 100,000 population 2011                                 0.338506
# Rate of CYIC 2011                                                                 0.388663
# Rate of Youth Charged per 100,000 population 2016                                 0.297200
# Rate of Children Living Low-Income Households 2016                                0.335655
# Rate of Population with No Degree 2016                                            1.000000
# Youth Crime Severity Index 2011                                                   0.689674
# Rate of Children in lone-parent families 2016                                     0.919566
# Rate of Children in lone-parent families 2011                                     0.884953
# Rates of households with violence 2011                                            0.905634
# Rates of households with violence 2016                                            0.884933
# Rate of Population with No Degree 2011                                            0.990593
# Average Household Size                                                           -0.353191
# Vegetable Consumption per Region 2011                                            -0.520322
# Rate of Youth in Correctional Services 2011                                       0.398542
# Rate of Youth in Correctional Services 2016                                       0.138803
# Alcohol Overdose Rate                                                             0.271287
# Suicide Rate 2011                                                                 0.944353
# Suicide Rate 2016                                                                 0.966116
# Homicide Rate 2011                                                                0.923739
# Homicide Rate 2016                                                               -0.284125
# Daily Smokers per Region 2016                                                     0.953358
# Daily Smokers per Region 2011                                                     0.938707
#
#                                                     Youth Crime Severity Index 2011  \
# Rate of Youth Charged per 100,000 population 2011                          0.846743
# Rate of CYIC 2011                                                          0.739079
# Rate of Youth Charged per 100,000 population 2016                          0.832524
# Rate of Children Living Low-Income Households 2016                         0.135691
# Rate of Population with No Degree 2016                                     0.689674
# Youth Crime Severity Index 2011                                            1.000000
# Rate of Children in lone-parent families 2016                              0.790201
# Rate of Children in lone-parent families 2011                              0.777696
# Rates of households with violence 2011                                     0.878495
# Rates of households with violence 2016                                     0.898883
# Rate of Population with No Degree 2011                                     0.687701
# Average Household Size                                                     0.195219
# Vegetable Consumption per Region 2011                                     -0.630426
# Rate of Youth in Correctional Services 2011                                0.798116
# Rate of Youth in Correctional Services 2016                                0.436225
# Alcohol Overdose Rate                                                      0.764675
# Suicide Rate 2011                                                          0.559841
# Suicide Rate 2016                                                          0.734315
# Homicide Rate 2011                                                         0.574489
# Homicide Rate 2016                                                         0.219206
# Daily Smokers per Region 2016                                              0.729644
# Daily Smokers per Region 2011                                              0.761406
#
#                                                     Rate of Children in lone-parent families 2016  \
# Rate of Youth Charged per 100,000 population 2011                                        0.432810
# Rate of CYIC 2011                                                                        0.484712
# Rate of Youth Charged per 100,000 population 2016                                        0.403650
# Rate of Children Living Low-Income Households 2016                                       0.340260
# Rate of Population with No Degree 2016                                                   0.919566
# Youth Crime Severity Index 2011                                                          0.790201
# Rate of Children in lone-parent families 2016                                            1.000000
# Rate of Children in lone-parent families 2011                                            0.990944
# Rates of households with violence 2011                                                   0.951891
# Rates of households with violence 2016                                                   0.942300
# Rate of Population with No Degree 2011                                                   0.890938
# Average Household Size                                                                   0.128555
# Vegetable Consumption per Region 2011                                                   -0.483328
# Rate of Youth in Correctional Services 2011                                              0.446880
# Rate of Youth in Correctional Services 2016                                              0.240474
# Alcohol Overdose Rate                                                                    0.470936
# Suicide Rate 2011                                                                        0.890331
# Suicide Rate 2016                                                                        0.945876
# Homicide Rate 2011                                                                       0.838867
# Homicide Rate 2016                                                                      -0.027162
# Daily Smokers per Region 2016                                                            0.955819
# Daily Smokers per Region 2011                                                            0.973257
#
#                                                     Rate of Children in lone-parent families 2011  \
# Rate of Youth Charged per 100,000 population 2011                                        0.428049
# Rate of CYIC 2011                                                                        0.508538
# Rate of Youth Charged per 100,000 population 2016                                        0.412541
# Rate of Children Living Low-Income Households 2016                                       0.473659
# Rate of Population with No Degree 2016                                                   0.884953
# Youth Crime Severity Index 2011                                                          0.777696
# Rate of Children in lone-parent families 2016                                            0.990944
# Rate of Children in lone-parent families 2011                                            1.000000
# Rates of households with violence 2011                                                   0.938843
# Rates of households with violence 2016                                                   0.930902
# Rate of Population with No Degree 2011                                                   0.856887
# Average Household Size                                                                   0.124159
# Vegetable Consumption per Region 2011                                                   -0.481206
# Rate of Youth in Correctional Services 2011                                              0.429754
# Rate of Youth in Correctional Services 2016                                              0.297616
# Alcohol Overdose Rate                                                                    0.492875
# Suicide Rate 2011                                                                        0.868694
# Suicide Rate 2016                                                                        0.928515
# Homicide Rate 2011                                                                       0.803306
# Homicide Rate 2016                                                                       0.065914
# Daily Smokers per Region 2016                                                            0.950891
# Daily Smokers per Region 2011                                                            0.974568
#
#                                                     Rates of households with violence 2011  \
# Rate of Youth Charged per 100,000 population 2011                                 0.538931
# Rate of CYIC 2011                                                                 0.564025
# Rate of Youth Charged per 100,000 population 2016                                 0.519076
# Rate of Children Living Low-Income Households 2016                               -0.185717
# Rate of Population with No Degree 2016                                            0.905634
# Youth Crime Severity Index 2011                                                   0.878495
# Rate of Children in lone-parent families 2016                                     0.951891
# Rate of Children in lone-parent families 2011                                     0.938843
# Rates of households with violence 2011                                            1.000000
# Rates of households with violence 2016                                            0.998152
# Rate of Population with No Degree 2011                                            0.878272
# Average Household Size                                                           -0.122006
# Vegetable Consumption per Region 2011                                            -0.614903
# Rate of Youth in Correctional Services 2011                                       0.524799
# Rate of Youth in Correctional Services 2016                                       0.183070
# Alcohol Overdose Rate                                                             0.631531
# Suicide Rate 2011                                                                 0.829318
# Suicide Rate 2016                                                                 0.929458
# Homicide Rate 2011                                                                0.781062
# Homicide Rate 2016                                                               -0.033615
# Daily Smokers per Region 2016                                                     0.943660
# Daily Smokers per Region 2011                                                     0.960261
#
#                                                     Rates of households with violence 2016  \
# Rate of Youth Charged per 100,000 population 2011                                 0.568104
# Rate of CYIC 2011                                                                 0.601320
# Rate of Youth Charged per 100,000 population 2016                                 0.553051
# Rate of Children Living Low-Income Households 2016                               -0.210902
# Rate of Population with No Degree 2016                                            0.884933
# Youth Crime Severity Index 2011                                                   0.898883
# Rate of Children in lone-parent families 2016                                     0.942300
# Rate of Children in lone-parent families 2011                                     0.930902
# Rates of households with violence 2011                                            0.998152
# Rates of households with violence 2016                                            1.000000
# Rate of Population with No Degree 2011                                            0.858473
# Average Household Size                                                            0.014249
# Vegetable Consumption per Region 2011                                            -0.612398
# Rate of Youth in Correctional Services 2011                                       0.555124
# Rate of Youth in Correctional Services 2016                                       0.207518
# Alcohol Overdose Rate                                                             0.668025
# Suicide Rate 2011                                                                 0.800788
# Suicide Rate 2016                                                                 0.913439
# Homicide Rate 2011                                                                0.753630
# Homicide Rate 2016                                                                0.010722
# Daily Smokers per Region 2016                                                     0.927786
# Daily Smokers per Region 2011                                                     0.948052
#
#                                                     ...  \
# Rate of Youth Charged per 100,000 population 2011   ...
# Rate of CYIC 2011                                   ...
# Rate of Youth Charged per 100,000 population 2016   ...
# Rate of Children Living Low-Income Households 2016  ...
# Rate of Population with No Degree 2016              ...
# Youth Crime Severity Index 2011                     ...
# Rate of Children in lone-parent families 2016       ...
# Rate of Children in lone-parent families 2011       ...
# Rates of households with violence 2011              ...
# Rates of households with violence 2016              ...
# Rate of Population with No Degree 2011              ...
# Average Household Size                              ...
# Vegetable Consumption per Region 2011               ...
# Rate of Youth in Correctional Services 2011         ...
# Rate of Youth in Correctional Services 2016         ...
# Alcohol Overdose Rate                               ...
# Suicide Rate 2011                                   ...
# Suicide Rate 2016                                   ...
# Homicide Rate 2011                                  ...
# Homicide Rate 2016                                  ...
# Daily Smokers per Region 2016                       ...
# Daily Smokers per Region 2011                       ...
#
#                                                     Vegetable Consumption per Region 2011  \
# Rate of Youth Charged per 100,000 population 2011                               -0.461343
# Rate of CYIC 2011                                                               -0.363625
# Rate of Youth Charged per 100,000 population 2016                               -0.450445
# Rate of Children Living Low-Income Households 2016                              -0.599164
# Rate of Population with No Degree 2016                                          -0.520322
# Youth Crime Severity Index 2011                                                 -0.630426
# Rate of Children in lone-parent families 2016                                   -0.483328
# Rate of Children in lone-parent families 2011                                   -0.481206
# Rates of households with violence 2011                                          -0.614903
# Rates of households with violence 2016                                          -0.612398
# Rate of Population with No Degree 2011                                          -0.516286
# Average Household Size                                                          -0.329292
# Vegetable Consumption per Region 2011                                            1.000000
# Rate of Youth in Correctional Services 2011                                     -0.547041
# Rate of Youth in Correctional Services 2016                                      0.033752
# Alcohol Overdose Rate                                                           -0.543173
# Suicide Rate 2011                                                               -0.345508
# Suicide Rate 2016                                                               -0.494979
# Homicide Rate 2011                                                              -0.406332
# Homicide Rate 2016                                                               0.115621
# Daily Smokers per Region 2016                                                   -0.522489
# Daily Smokers per Region 2011                                                   -0.509729
#
#                                                     Rate of Youth in Correctional Services 2011  \
# Rate of Youth Charged per 100,000 population 2011                                      0.781349
# Rate of CYIC 2011                                                                      0.757253
# Rate of Youth Charged per 100,000 population 2016                                      0.793926
# Rate of Children Living Low-Income Households 2016                                     0.425904
# Rate of Population with No Degree 2016                                                 0.398542
# Youth Crime Severity Index 2011                                                        0.798116
# Rate of Children in lone-parent families 2016                                          0.446880
# Rate of Children in lone-parent families 2011                                          0.429754
# Rates of households with violence 2011                                                 0.524799
# Rates of households with violence 2016                                                 0.555124
# Rate of Population with No Degree 2011                                                 0.431939
# Average Household Size                                                                 0.098338
# Vegetable Consumption per Region 2011                                                 -0.547041
# Rate of Youth in Correctional Services 2011                                            1.000000
# Rate of Youth in Correctional Services 2016                                            0.609344
# Alcohol Overdose Rate                                                                  0.575705
# Suicide Rate 2011                                                                      0.178891
# Suicide Rate 2016                                                                      0.344126
# Homicide Rate 2011                                                                     0.285388
# Homicide Rate 2016                                                                     0.247831
# Daily Smokers per Region 2016                                                          0.378782
# Daily Smokers per Region 2011                                                          0.402838
#
#                                                     Rate of Youth in Correctional Services 2016  \
# Rate of Youth Charged per 100,000 population 2011                                      0.641159
# Rate of CYIC 2011                                                                      0.667074
# Rate of Youth Charged per 100,000 population 2016                                      0.701129
# Rate of Children Living Low-Income Households 2016                                     0.349254
# Rate of Population with No Degree 2016                                                 0.138803
# Youth Crime Severity Index 2011                                                        0.436225
# Rate of Children in lone-parent families 2016                                          0.240474
# Rate of Children in lone-parent families 2011                                          0.297616
# Rates of households with violence 2011                                                 0.183070
# Rates of households with violence 2016                                                 0.207518
# Rate of Population with No Degree 2011                                                 0.211322
# Average Household Size                                                                 0.044427
# Vegetable Consumption per Region 2011                                                  0.033752
# Rate of Youth in Correctional Services 2011                                            0.609344
# Rate of Youth in Correctional Services 2016                                            1.000000
# Alcohol Overdose Rate                                                                  0.114989
# Suicide Rate 2011                                                                      0.135821
# Suicide Rate 2016                                                                      0.204466
# Homicide Rate 2011                                                                     0.169383
# Homicide Rate 2016                                                                     0.676342
# Daily Smokers per Region 2016                                                          0.199443
# Daily Smokers per Region 2011                                                          0.236570
#
#                                                     Alcohol Overdose Rate  \
# Rate of Youth Charged per 100,000 population 2011                0.581050
# Rate of CYIC 2011                                                0.609035
# Rate of Youth Charged per 100,000 population 2016                0.615727
# Rate of Children Living Low-Income Households 2016              -0.217784
# Rate of Population with No Degree 2016                           0.271287
# Youth Crime Severity Index 2011                                  0.764675
# Rate of Children in lone-parent families 2016                    0.470936
# Rate of Children in lone-parent families 2011                    0.492875
# Rates of households with violence 2011                           0.631531
# Rates of households with violence 2016                           0.668025
# Rate of Population with No Degree 2011                           0.232104
# Average Household Size                                          -0.083969
# Vegetable Consumption per Region 2011                           -0.543173
# Rate of Youth in Correctional Services 2011                      0.575705
# Rate of Youth in Correctional Services 2016                      0.114989
# Alcohol Overdose Rate                                            1.000000
# Suicide Rate 2011                                                0.111122
# Suicide Rate 2016                                                0.333130
# Homicide Rate 2011                                               0.057285
# Homicide Rate 2016                                               0.371295
# Daily Smokers per Region 2016                                    0.411175
# Daily Smokers per Region 2011                                    0.456053
#
#                                                     Suicide Rate 2011  \
# Rate of Youth Charged per 100,000 population 2011            0.249146
# Rate of CYIC 2011                                            0.262836
# Rate of Youth Charged per 100,000 population 2016            0.192710
# Rate of Children Living Low-Income Households 2016          -0.371731
# Rate of Population with No Degree 2016                       0.944353
# Youth Crime Severity Index 2011                              0.559841
# Rate of Children in lone-parent families 2016                0.890331
# Rate of Children in lone-parent families 2011                0.868694
# Rates of households with violence 2011                       0.829318
# Rates of households with violence 2016                       0.800788
# Rate of Population with No Degree 2011                       0.925574
# Average Household Size                                      -0.730382
# Vegetable Consumption per Region 2011                       -0.345508
# Rate of Youth in Correctional Services 2011                  0.178891
# Rate of Youth in Correctional Services 2016                  0.135821
# Alcohol Overdose Rate                                        0.111122
# Suicide Rate 2011                                            1.000000
# Suicide Rate 2016                                            0.962656
# Homicide Rate 2011                                           0.954663
# Homicide Rate 2016                                          -0.260909
# Daily Smokers per Region 2016                                0.922677
# Daily Smokers per Region 2011                                0.916300
#
#                                                     Suicide Rate 2016  \
# Rate of Youth Charged per 100,000 population 2011            0.419294
# Rate of CYIC 2011                                            0.434925
# Rate of Youth Charged per 100,000 population 2016            0.374009
# Rate of Children Living Low-Income Households 2016           0.116131
# Rate of Population with No Degree 2016                       0.966116
# Youth Crime Severity Index 2011                              0.734315
# Rate of Children in lone-parent families 2016                0.945876
# Rate of Children in lone-parent families 2011                0.928515
# Rates of households with violence 2011                       0.929458
# Rates of households with violence 2016                       0.913439
# Rate of Population with No Degree 2011                       0.951682
# Average Household Size                                      -0.212067
# Vegetable Consumption per Region 2011                       -0.494979
# Rate of Youth in Correctional Services 2011                  0.344126
# Rate of Youth in Correctional Services 2016                  0.204466
# Alcohol Overdose Rate                                        0.333130
# Suicide Rate 2011                                            0.962656
# Suicide Rate 2016                                            1.000000
# Homicide Rate 2011                                           0.917979
# Homicide Rate 2016                                          -0.115486
# Daily Smokers per Region 2016                                0.970309
# Daily Smokers per Region 2011                                0.965851
#
#                                                     Homicide Rate 2011  \
# Rate of Youth Charged per 100,000 population 2011             0.300095
# Rate of CYIC 2011                                             0.312855
# Rate of Youth Charged per 100,000 population 2016             0.229549
# Rate of Children Living Low-Income Households 2016            0.198797
# Rate of Population with No Degree 2016                        0.923739
# Youth Crime Severity Index 2011                               0.574489
# Rate of Children in lone-parent families 2016                 0.838867
# Rate of Children in lone-parent families 2011                 0.803306
# Rates of households with violence 2011                        0.781062
# Rates of households with violence 2016                        0.753630
# Rate of Population with No Degree 2011                        0.907147
# Average Household Size                                        0.326854
# Vegetable Consumption per Region 2011                        -0.406332
# Rate of Youth in Correctional Services 2011                   0.285388
# Rate of Youth in Correctional Services 2016                   0.169383
# Alcohol Overdose Rate                                         0.057285
# Suicide Rate 2011                                             0.954663
# Suicide Rate 2016                                             0.917979
# Homicide Rate 2011                                            1.000000
# Homicide Rate 2016                                           -0.315146
# Daily Smokers per Region 2016                                 0.844010
# Daily Smokers per Region 2011                                 0.847528
#
#                                                     Homicide Rate 2016  \
# Rate of Youth Charged per 100,000 population 2011             0.396558
# Rate of CYIC 2011                                             0.521534
# Rate of Youth Charged per 100,000 population 2016             0.484720
# Rate of Children Living Low-Income Households 2016            0.117713
# Rate of Population with No Degree 2016                       -0.284125
# Youth Crime Severity Index 2011                               0.219206
# Rate of Children in lone-parent families 2016                -0.027162
# Rate of Children in lone-parent families 2011                 0.065914
# Rates of households with violence 2011                       -0.033615
# Rates of households with violence 2016                        0.010722
# Rate of Population with No Degree 2011                       -0.250605
# Average Household Size                                        0.353917
# Vegetable Consumption per Region 2011                         0.115621
# Rate of Youth in Correctional Services 2011                   0.247831
# Rate of Youth in Correctional Services 2016                   0.676342
# Alcohol Overdose Rate                                         0.371295
# Suicide Rate 2011                                            -0.260909
# Suicide Rate 2016                                            -0.115486
# Homicide Rate 2011                                           -0.315146
# Homicide Rate 2016                                            1.000000
# Daily Smokers per Region 2016                                -0.092678
# Daily Smokers per Region 2011                                -0.035775
#
#                                                     Daily Smokers per Region 2016  \
# Rate of Youth Charged per 100,000 population 2011                        0.381827
# Rate of CYIC 2011                                                        0.402430
# Rate of Youth Charged per 100,000 population 2016                        0.351810
# Rate of Children Living Low-Income Households 2016                       0.329166
# Rate of Population with No Degree 2016                                   0.953358
# Youth Crime Severity Index 2011                                          0.729644
# Rate of Children in lone-parent families 2016                            0.955819
# Rate of Children in lone-parent families 2011                            0.950891
# Rates of households with violence 2011                                   0.943660
# Rates of households with violence 2016                                   0.927786
# Rate of Population with No Degree 2011                                   0.939124
# Average Household Size                                                  -0.659891
# Vegetable Consumption per Region 2011                                   -0.522489
# Rate of Youth in Correctional Services 2011                              0.378782
# Rate of Youth in Correctional Services 2016                              0.199443
# Alcohol Overdose Rate                                                    0.411175
# Suicide Rate 2011                                                        0.922677
# Suicide Rate 2016                                                        0.970309
# Homicide Rate 2011                                                       0.844010
# Homicide Rate 2016                                                      -0.092678
# Daily Smokers per Region 2016                                            1.000000
# Daily Smokers per Region 2011                                            0.988155
#
#                                                     Daily Smokers per Region 2011
# Rate of Youth Charged per 100,000 population 2011                        0.412415
# Rate of CYIC 2011                                                        0.461702
# Rate of Youth Charged per 100,000 population 2016                        0.393463
# Rate of Children Living Low-Income Households 2016                       0.042891
# Rate of Population with No Degree 2016                                   0.938707
# Youth Crime Severity Index 2011                                          0.761406
# Rate of Children in lone-parent families 2016                            0.973257
# Rate of Children in lone-parent families 2011                            0.974568
# Rates of households with violence 2011                                   0.960261
# Rates of households with violence 2016                                   0.948052
# Rate of Population with No Degree 2011                                   0.919146
# Average Household Size                                                  -0.614866
# Vegetable Consumption per Region 2011                                   -0.509729
# Rate of Youth in Correctional Services 2011                              0.402838
# Rate of Youth in Correctional Services 2016                              0.236570
# Alcohol Overdose Rate                                                    0.456053
# Suicide Rate 2011                                                        0.916300
# Suicide Rate 2016                                                        0.965851
# Homicide Rate 2011                                                       0.847528
# Homicide Rate 2016                                                      -0.035775
# Daily Smokers per Region 2016                                            0.988155
# Daily Smokers per Region 2011                                            1.000000
#
# [22 rows x 22 columns]

# %%
#Let's look strictly at the correlation between the severity of crimes and the rates of household violence
import pandas as pd


file=pd.read_csv('crime_test.csv')
file.corr()

#High correlation between rates of household violence and non-violent crime severity index.
    #2011; 90.4%
    #2015; 91.2%
    #2016; 95.5%

    
#What can we understand from this?
#In regions with higher rates of household violence, youth tend to commit more serious non-violent crimes.
#Why may this be?
# Out:
#                                               Rates of households with violence 2011  \
# Rates of households with violence 2011                                      1.000000
# Youth Crime Severity Index 2011                                             0.878495
# Youth Violent Crime Severity Index 2011                                     0.641683
# Youth Non- Violent Crime Severity Index 2011                                0.904750
# Rates of households with violence 2015                                      0.977318
# Youth Crime Severity Index 2015                                             0.866486
# Youth Violent Crime Severity Index 2015                                     0.829026
# Youth Non-Violent Crime Severity Index 2015                                 0.866400
# Rates of households with violence 2016                                      0.998152
# Youth Crime Severity Index 2016                                             0.901497
# Youth Violent Crime Severity Index 2016                                     0.687855
# Youth Non-Violent Crime Severity Index 2016                                 0.942868
#
#                                               Youth Crime Severity Index 2011  \
# Rates of households with violence 2011                               0.878495
# Youth Crime Severity Index 2011                                      1.000000
# Youth Violent Crime Severity Index 2011                              0.865128
# Youth Non- Violent Crime Severity Index 2011                         0.987784
# Rates of households with violence 2015                               0.860377
# Youth Crime Severity Index 2015                                      0.892824
# Youth Violent Crime Severity Index 2015                              0.921743
# Youth Non-Violent Crime Severity Index 2015                          0.868716
# Rates of households with violence 2016                               0.898883
# Youth Crime Severity Index 2016                                      0.939898
# Youth Violent Crime Severity Index 2016                              0.778597
# Youth Non-Violent Crime Severity Index 2016                          0.960495
#
#                                               Youth Violent Crime Severity Index 2011  \
# Rates of households with violence 2011                                       0.641683
# Youth Crime Severity Index 2011                                              0.865128
# Youth Violent Crime Severity Index 2011                                      1.000000
# Youth Non- Violent Crime Severity Index 2011                                 0.776407
# Rates of households with violence 2015                                       0.636600
# Youth Crime Severity Index 2015                                              0.709224
# Youth Violent Crime Severity Index 2015                                      0.825250
# Youth Non-Violent Crime Severity Index 2015                                  0.656967
# Rates of households with violence 2016                                       0.672445
# Youth Crime Severity Index 2016                                              0.772610
# Youth Violent Crime Severity Index 2016                                      0.734611
# Youth Non-Violent Crime Severity Index 2016                                  0.755175
#
#                                               Youth Non- Violent Crime Severity Index 2011  \
# Rates of households with violence 2011                                            0.904750
# Youth Crime Severity Index 2011                                                   0.987784
# Youth Violent Crime Severity Index 2011                                           0.776407
# Youth Non- Violent Crime Severity Index 2011                                      1.000000
# Rates of households with violence 2015                                            0.883567
# Youth Crime Severity Index 2015                                                   0.901591
# Youth Violent Crime Severity Index 2015                                           0.901714
# Youth Non-Violent Crime Severity Index 2015                                       0.887593
# Rates of households with violence 2016                                            0.920795
# Youth Crime Severity Index 2016                                                   0.941056
# Youth Violent Crime Severity Index 2016                                           0.750071
# Youth Non-Violent Crime Severity Index 2016                                       0.972390
#
#                                               Rates of households with violence 2015  \
# Rates of households with violence 2011                                      0.977318
# Youth Crime Severity Index 2011                                             0.860377
# Youth Violent Crime Severity Index 2011                                     0.636600
# Youth Non- Violent Crime Severity Index 2011                                0.883567
# Rates of households with violence 2015                                      1.000000
# Youth Crime Severity Index 2015                                             0.912986
# Youth Violent Crime Severity Index 2015                                     0.875958
# Youth Non-Violent Crime Severity Index 2015                                 0.912023
# Rates of households with violence 2016                                      0.975143
# Youth Crime Severity Index 2016                                             0.936552
# Youth Violent Crime Severity Index 2016                                     0.783611
# Youth Non-Violent Crime Severity Index 2016                                 0.953411
#
#                                               Youth Crime Severity Index 2015  \
# Rates of households with violence 2011                               0.866486
# Youth Crime Severity Index 2011                                      0.892824
# Youth Violent Crime Severity Index 2011                              0.709224
# Youth Non- Violent Crime Severity Index 2011                         0.901591
# Rates of households with violence 2015                               0.912986
# Youth Crime Severity Index 2015                                      1.000000
# Youth Violent Crime Severity Index 2015                              0.967779
# Youth Non-Violent Crime Severity Index 2015                          0.995979
# Rates of households with violence 2016                               0.882794
# Youth Crime Severity Index 2016                                      0.988343
# Youth Violent Crime Severity Index 2016                              0.928932
# Youth Non-Violent Crime Severity Index 2016                          0.967062
#
#                                               Youth Violent Crime Severity Index 2015  \
# Rates of households with violence 2011                                       0.829026
# Youth Crime Severity Index 2011                                              0.921743
# Youth Violent Crime Severity Index 2011                                      0.825250
# Youth Non- Violent Crime Severity Index 2011                                 0.901714
# Rates of households with violence 2015                                       0.875958
# Youth Crime Severity Index 2015                                              0.967779
# Youth Violent Crime Severity Index 2015                                      1.000000
# Youth Non-Violent Crime Severity Index 2015                                  0.941330
# Rates of households with violence 2016                                       0.848623
# Youth Crime Severity Index 2016                                              0.979173
# Youth Violent Crime Severity Index 2016                                      0.949514
# Youth Non-Violent Crime Severity Index 2016                                  0.948103
#
#                                               Youth Non-Violent Crime Severity Index 2015  \
# Rates of households with violence 2011                                           0.866400
# Youth Crime Severity Index 2011                                                  0.868716
# Youth Violent Crime Severity Index 2011                                          0.656967
# Youth Non- Violent Crime Severity Index 2011                                     0.887593
# Rates of households with violence 2015                                           0.912023
# Youth Crime Severity Index 2015                                                  0.995979
# Youth Violent Crime Severity Index 2015                                          0.941330
# Youth Non-Violent Crime Severity Index 2015                                      1.000000
# Rates of households with violence 2016                                           0.881287
# Youth Crime Severity Index 2016                                                  0.976302
# Youth Violent Crime Severity Index 2016                                          0.907220
# Youth Non-Violent Crime Severity Index 2016                                      0.958835
#
#                                               Rates of households with violence 2016  \
# Rates of households with violence 2011                                      0.998152
# Youth Crime Severity Index 2011                                             0.898883
# Youth Violent Crime Severity Index 2011                                     0.672445
# Youth Non- Violent Crime Severity Index 2011                                0.920795
# Rates of households with violence 2015                                      0.975143
# Youth Crime Severity Index 2015                                             0.882794
# Youth Violent Crime Severity Index 2015                                     0.848623
# Youth Non-Violent Crime Severity Index 2015                                 0.881287
# Rates of households with violence 2016                                      1.000000
# Youth Crime Severity Index 2016                                             0.916347
# Youth Violent Crime Severity Index 2016                                     0.706912
# Youth Non-Violent Crime Severity Index 2016                                 0.955457
#
#                                               Youth Crime Severity Index 2016  \
# Rates of households with violence 2011                               0.901497
# Youth Crime Severity Index 2011                                      0.939898
# Youth Violent Crime Severity Index 2011                              0.772610
# Youth Non- Violent Crime Severity Index 2011                         0.941056
# Rates of households with violence 2015                               0.936552
# Youth Crime Severity Index 2015                                      0.988343
# Youth Violent Crime Severity Index 2015                              0.979173
# Youth Non-Violent Crime Severity Index 2015                          0.976302
# Rates of households with violence 2016                               0.916347
# Youth Crime Severity Index 2016                                      1.000000
# Youth Violent Crime Severity Index 2016                              0.915145
# Youth Non-Violent Crime Severity Index 2016                          0.988392
#
#                                               Youth Violent Crime Severity Index 2016  \
# Rates of households with violence 2011                                       0.687855
# Youth Crime Severity Index 2011                                              0.778597
# Youth Violent Crime Severity Index 2011                                      0.734611
# Youth Non- Violent Crime Severity Index 2011                                 0.750071
# Rates of households with violence 2015                                       0.783611
# Youth Crime Severity Index 2015                                              0.928932
# Youth Violent Crime Severity Index 2015                                      0.949514
# Youth Non-Violent Crime Severity Index 2015                                  0.907220
# Rates of households with violence 2016                                       0.706912
# Youth Crime Severity Index 2016                                              0.915145
# Youth Violent Crime Severity Index 2016                                      1.000000
# Youth Non-Violent Crime Severity Index 2016                                  0.843304
#
#                                               Youth Non-Violent Crime Severity Index 2016
# Rates of households with violence 2011                                           0.942868
# Youth Crime Severity Index 2011                                                  0.960495
# Youth Violent Crime Severity Index 2011                                          0.755175
# Youth Non- Violent Crime Severity Index 2011                                     0.972390
# Rates of households with violence 2015                                           0.953411
# Youth Crime Severity Index 2015                                                  0.967062
# Youth Violent Crime Severity Index 2015                                          0.948103
# Youth Non-Violent Crime Severity Index 2015                                      0.958835
# Rates of households with violence 2016                                           0.955457
# Youth Crime Severity Index 2016                                                  0.988392
# Youth Violent Crime Severity Index 2016                                          0.843304
# Youth Non-Violent Crime Severity Index 2016                                      1.000000

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

file = pd.read_csv('provincess.csv')


#I created a new dataframe that has statistics for certain factors in the 2012 year.
#Please do not get confused by the fact that it says 2016; it is from 2012.


#I used data from 2016 to make predicions about the youth crime severity of a random year.
#Then I created a column to calculate the difference between the actual and predicted number.

r = smf.gls('Q("Youth Crime Severity Index 2016")~Q("Rates of households with violence 2016")',data=file).fit()
#r.summary()
d={'provinces':['Manitoba','Quebec','Ontario','PEI','Nunavut','Saskatchewan','BC','NB','Yukon','Alberta','NS','Newfoundland','NT'],'Rates of households with violence 2016':[323.7,217.8,131,144.3,2355.5,410.3,189.9,190.1,811,238.5,172.5,215.8,1767.1],
                      "Daily Smokers per Region 2016":[15.4,18.5,14.3,18.3,48.8,15.2,10.7,18.6,22.8,16.7,18.3,21,28.6],
                       "Rate of Children in lone-parent families 2016":[17.3,16.6,17.3,16.2,28.4,17.4,15.7,16.1,21.9,14.6,17.9,15.9,22.9]
   ,'Actual Youth Crime Severity 2012':[144.46,64.95,67.42,70.85,341.07,207.52,57.51,80.28,178.72,79.86,111.75,65.42,385.62]}
df=pd.DataFrame(data=d)
df['Predicted Youth Crime Severity 2012']=r.predict(df)
df[['Predicted Youth Crime Severity 2012','Actual Youth Crime Severity 2012']].astype('int64')
df['Difference']=abs(df['Predicted Youth Crime Severity 2012']-df['Actual Youth Crime Severity 2012'])
df
# Out:
#        provinces  Rates of households with violence 2016  \
# 0       Manitoba                                   323.7
# 1         Quebec                                   217.8
# 2        Ontario                                   131.0
# 3            PEI                                   144.3
# 4        Nunavut                                  2355.5
# 5   Saskatchewan                                   410.3
# 6             BC                                   189.9
# 7             NB                                   190.1
# 8          Yukon                                   811.0
# 9        Alberta                                   238.5
# 10            NS                                   172.5
# 11  Newfoundland                                   215.8
# 12            NT                                  1767.1
#
#     Daily Smokers per Region 2016  \
# 0                            15.4
# 1                            18.5
# 2                            14.3
# 3                            18.3
# 4                            48.8
# 5                            15.2
# 6                            10.7
# 7                            18.6
# 8                            22.8
# 9                            16.7
# 10                           18.3
# 11                           21.0
# 12                           28.6
#
#     Rate of Children in lone-parent families 2016  \
# 0                                            17.3
# 1                                            16.6
# 2                                            17.3
# 3                                            16.2
# 4                                            28.4
# 5                                            17.4
# 6                                            15.7
# 7                                            16.1
# 8                                            21.9
# 9                                            14.6
# 10                                           17.9
# 11                                           15.9
# 12                                           22.9
#
#     Actual Youth Crime Severity 2012  Predicted Youth Crime Severity 2012  \
# 0                             144.46                            88.719499
# 1                              64.95                            76.524686
# 2                              67.42                            66.529316
# 3                              70.85                            68.060865
# 4                             341.07                           322.689471
# 5                             207.52                            98.691838
# 6                              57.51                            73.311889
# 7                              80.28                            73.334919
# 8                             178.72                           144.834061
# 9                              79.86                            78.908375
# 10                            111.75                            71.308208
# 11                             65.42                            76.294378
# 12                            385.62                           254.932836
#
#     Difference
# 0    55.740501
# 1    11.574686
# 2     0.890684
# 3     2.789135
# 4    18.380529
# 5   108.828162
# 6    15.801889
# 7     6.945081
# 8    33.885939
# 9     0.951625
# 10   40.441792
# 11   10.874378
# 12  130.687164

# %%
# I then summed up the total errors as well as total statistics in the actual youth severity to see roughly how accurate my predictions were.

#I thought that this was a fair way of measuring accuracy since the higher a given number is, the more likely it is for a prediction
#to be more off.
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

file = pd.read_csv('provincess.csv')
#file.dropna(axis=1)
#file = file.drop(file.columns[[8,9,11,12]],axis=1)
#file.corr(method='pearson')

#file = file.drop(file.columns[[8,9,11,12]],axis=1)
#file.corr(method='pearson')

r = smf.gls('Q("Youth Crime Severity Index 2016")~Q("Rates of households with violence 2016")',data=file).fit()
#r.summary()

#I created a new dataframe that has statistics for certain factors in the 2012 year.
#Please do not get confused by the fact that it says 2016; it is from 2012.

d={'provinces':['Manitoba','Quebec','Ontario','PEI','Nunavut','Saskatchewan','BC','NB','Yukon','Alberta','NS','Newfoundland','NT'],'Rates of households with violence 2016':[323.7,217.8,131,144.3,2355.5,410.3,189.9,190.1,811,238.5,172.5,215.8,1767.1],
                      "Daily Smokers per Region 2016":[15.4,18.5,14.3,18.3,48.8,15.2,10.7,18.6,22.8,16.7,18.3,21,28.6],
                       "Rate of Children in lone-parent families 2016":[17.3,16.6,17.3,16.2,28.4,17.4,15.7,16.1,21.9,14.6,17.9,15.9,22.9]
   ,'actual':[144.46,64.95,67.42,70.85,341.07,207.52,57.51,80.28,178.72,79.86,111.75,65.42,385.62]}
df=pd.DataFrame(data=d)
df['predicted']=r.predict(df)
df[['predicted','actual']].astype('int64')
df['difference']=abs(df['predicted']-df['actual'])
q=df['difference'].sum()
w=df['actual'].sum()
print(100-(q/w)*100)


#Predicting Youth Crime Severity Index of a random year gives us roughly a 76% accuracy rate.
# Out:
# 76.40484601950382

# %%
#I wanted to see if I could predict rates of household violence for any given year as well.

#For this, I found that looking at suicide rates and daily smokers of a given region were pretty accurate.


#NOTE: Again, the data in the dataframe ar is 2012 data.

import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

file = pd.read_csv('provincess.csv')
#file.dropna(axis=1)
#file = file.drop(file.columns[[8,9,11,12]],axis=1)
#file.corr(method='pearson')

#file = file.drop(file.columns[[8,9,11,12]],axis=1)
#file.corr(method='pearson')

r = smf.gls('Q("Rates of households with violence 2016")~Q("Rate of Children in lone-parent families 2016")+Q("Daily Smokers per Region 2016")+Q("Suicide Rate 2016")',data=file).fit()
#r.summary()
#2011
ar = {'Rate of Population with No Degree 2016':[17,15,12,13.5,44,16,9,16.5,12.5,12.5,13.5,20,22],
    'Rate of Children in lone-parent families 2016':[17.1,16.6,16.7,16.1,28.2,16.4,15.3,16.1,20.5,14.5,17.3,15.3,21.3],
    'Suicide Rate 2016':[11.5,14.1,8.9,8.9,68.6,13,10.8,14,14.1,12.8,11.6,10.5,13.6],
    'Daily Smokers per Region 2016':[18.7,19.8,16.3,19.1,59.7,19.2,14.2,18.8,29.3,17.7,18.1,19,34.3],
     'actual':[402,328,190,227,3294,583,271,283,867,321,246,305,2304]}

df=pd.DataFrame(data=ar)
df['predicted']=r.predict(df)
df[['predicted','actual']].astype('int64')
df['difference']=abs(df['predicted']-df['actual'])
df
#q=df['difference'].sum()
#r=df['actual'].sum()
#print(100-(q/r)*100)
#74.1%
# Out:
#     Rate of Population with No Degree 2016  \
# 0                                     17.0
# 1                                     15.0
# 2                                     12.0
# 3                                     13.5
# 4                                     44.0
# 5                                     16.0
# 6                                      9.0
# 7                                     16.5
# 8                                     12.5
# 9                                     12.5
# 10                                    13.5
# 11                                    20.0
# 12                                    22.0
#
#     Rate of Children in lone-parent families 2016  Suicide Rate 2016  \
# 0                                            17.1               11.5
# 1                                            16.6               14.1
# 2                                            16.7                8.9
# 3                                            16.1                8.9
# 4                                            28.2               68.6
# 5                                            16.4               13.0
# 6                                            15.3               10.8
# 7                                            16.1               14.0
# 8                                            20.5               14.1
# 9                                            14.5               12.8
# 10                                           17.3               11.6
# 11                                           15.3               10.5
# 12                                           21.3               13.6
#
#     Daily Smokers per Region 2016  actual    predicted  difference
# 0                            18.7     402   463.924332   61.924332
# 1                            19.8     328   548.059936  220.059936
# 2                            16.3     190   277.717618   87.717618
# 3                            19.1     227   349.501299  122.501299
# 4                            59.7    3294  4241.878902  947.878902
# 5                            19.2     583   483.326489   99.673511
# 6                            14.2     271   168.114580  102.885420
# 7                            18.8     283   478.016271  195.016271
# 8                            29.3     867  1137.826317  270.826317
# 9                            17.7     321   309.812399   11.187601
# 10                           18.1     246   455.452585  209.452585
# 11                           19.0     305   342.933497   37.933497
# 12                           34.3    2304  1361.445822  942.554178

# %%
#look at accuracy rate.

import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

file = pd.read_csv('provincess.csv')
#file.dropna(axis=1)
#file = file.drop(file.columns[[8,9,11,12]],axis=1)
#file.corr(method='pearson')

#file = file.drop(file.columns[[8,9,11,12]],axis=1)
#file.corr(method='pearson')

r = smf.gls('Q("Rates of households with violence 2016")~Q("Daily Smokers per Region 2016")+Q("Suicide Rate 2016")',data=file).fit()
#r.summary()
#2011
ar = {'Rate of Population with No Degree 2016':[17,15,12,13.5,44,16,9,16.5,12.5,12.5,13.5,20,22],
    'Rate of Children in lone-parent families 2016':[17.1,16.6,16.7,16.1,28.2,16.4,15.3,16.1,20.5,14.5,17.3,15.3,21.3],
    'Suicide Rate 2016':[11.5,14.1,8.9,8.9,68.6,13,10.8,14,14.1,12.8,11.6,10.5,13.6],
    'Daily Smokers per Region 2016':[18.7,19.8,16.3,19.1,59.7,19.2,14.2,18.8,29.3,17.7,18.1,19,34.3],
     'actual':[402,328,190,227,3294,583,271,283,867,321,246,305,2304]}

df=pd.DataFrame(data=ar)
df['predicted']=r.predict(df)
df['predicted']=abs(df['predicted'])
df[['predicted','actual']].astype('int64')
df['difference']=abs(df['predicted']-df['actual'])
#df
q=df['difference'].sum()
r=df['actual'].sum()
print(100-(q/r)*100)
#74.1%
# Out:
# 74.06342092018409

# %%
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier,LinearRegression,Ridge
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error
from sklearn import model_selection
from math import sqrt
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier 
file = pd.read_csv('provincesss.csv')
kf5 = KFold(n_splits=4,shuffle=True)
#____________

y=file["Rates of households with violence 2011"]
y=y.astype('int64')
X = file["Daily Smokers per Region 2011"]+file['Rate of Children in lone-parent families 2011']
X=X.astype('int64')
X=X.values.reshape(-1,1)
#train_review,test_review,train_sentiment,test_sentiment = train_test_split(X,y,test_size=0.2)

model = LinearRegression()
#model = RandomForestClassifier()

    
#bagger = text.CountVectorizer(stop_words = 'english')
final = []

for train_index,test_index in kf5.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    #print(train_index)
    #print(test_index)
    #X_train=bagger.fit_transform(X_train)
    #X_test = bagger.transform(X_test)
    
    model.fit(X_train,y_train)
    #print(model.score(X_train,y_train))
    y_pred = model.predict(X_test).reshape(-1,1)
    #final.append(model.score(y_pred,y_test))
    #print(y_pred)
    #print(y_test)
    predicted=(sqrt((mean_squared_error(y_pred,y_test))*len(y_test)))
    total=(y_test.sum())
    #print(predicted)
    #print(total)
    final.append((1-(predicted/total)))

print(final)
print(np.mean(final))
#prints accuracy score

#2011 rates range from 70-75%.
#2016 rates range from 55%-65%. This might be due to outliers (will be taken out with updates).
# Out:
# [0.7736392603864827, 0.8526674432013851, 0.782108335249855, 0.7171801787096382]
# 0.7813988043868403

# %%
#plot it on a graph
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = pd.read_csv('provincesss.csv')

#____________


y=file["Rates of households with violence 2016"]
y=y.astype('int64')
X = file["Rate of Children in lone-parent families 2016"]+file['Daily Smokers per Region 2016']
plt.scatter(X,y)

# %%
#Now to see if we can predict houesholds with violence and non-violence crime severity..
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier,LinearRegression,LogisticRegression,Ridge
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn import model_selection
from math import sqrt
from sklearn.ensemble import RandomForestClassifier 

file = pd.read_csv('provincesss.csv')
#file.drop(file.index[5],inplace=True)
#file=file.reset_index()
#file.drop(file.index[11],inplace=True)
#file=file.reset_index()
kf5 = KFold(n_splits=4,shuffle=True)


#____________

y=file["Youth Non-Violent Crime Severity Index 2016"]
y=y.astype('int64')

X = file["Rates of households with violence 2016"]
X=X.astype('int64')
X=np.log(X)
X=X.values.reshape(-1,1)
model =LinearRegression()
final = []

for train_index,test_index in kf5.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    #print(train_index)
    #print(test_index)
    #X_train=bagger.fit_transform(X_train)
    #X_test = bagger.transform(X_test)
    
    model.fit(X_train,y_train)
    #print(model.score(X_train,y_train))
    y_pred = model.predict(X_test).reshape(-1,1)
    y_pred = abs(y_pred)
    #final.append(model.score(y_pred,y_test))
    #print(y_pred)
    #print(y_test)
    predicted=((mean_absolute_error(y_pred,y_test))*len(y_test))
    total=(y_test.sum())
    #print(predicted)
    #print(total)
    final.append((1-(predicted/total)))

print(final)
print(np.mean(final))


#The mean of k-fold cross validations for 4 splits ranges from 69% to 79%.
# Out:
# [0.5242729791394947, 0.8222002240552841, 0.8627648991966365, 0.8255633447358696]
# 0.7587003617818212

# %%
#plot it on a graph
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = pd.read_csv('provincesss.csv')

kf5 = KFold(n_splits=4,shuffle=True)


y=file["Youth Non-Violent Crime Severity Index 2016"]
y=y.astype('int64')

X = file["Rates of households with violence 2016"]
X=X.astype('int64')
X=np.log(X)
plt.scatter(X,y)

#looks pretty linear on a graph.
